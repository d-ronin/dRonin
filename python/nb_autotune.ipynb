# %%
# %matplotlib inline

# Import all the numerical computing stuff we need...

from dronin import autotune
import numpy as np
import pandas
import math
from scipy import fftpack, signal
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import LinearAxis, Range1d, Span

output_notebook() # Tell bokeh to send plots to notebook

# And load up a datafile of autotune data.  In this file, the average
# motor commands and gyro responses from all 90-120 wobbles during the
# autotune sequence are stored.
df, time_step = autotune.read_autotune_from_autotown('ahFzfmRyb25pbi1hdXRvdG93bnIYCxILVHVuZVJlc3VsdHMYgICAsPibygkM')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a1f128db-8b65-47a6-b5a4-96fbdb2b49e0">Loading BokehJS ...</span>
#     </div>
# Autotune data: pts = 1024, aux_data_len = 0, timestep = 0.62ms

# %%
# next let's plot what the roll gyro does vs. the flight controller's roll command

p = figure(title="roll gyro vs actuators")
p.line(df.time, df.gyroX)
p.extra_y_ranges = { 'actuation' : Range1d(min(df.desiredX), max(df.desiredX)) }
p.line(df.time, df.desiredX, y_range_name='actuation', color="red")
p.add_layout(LinearAxis(y_range_name="actuation"), 'right')

show(p)

# Looks really nasty, huh?  This is the gyro data vs. the actuator data. They're clearly related
# but phase is off and shape is a fair bit different.
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1263bb32-da1e-459e-8038-8fd1e742978e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1263bb32-da1e-459e-8038-8fd1e742978e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1263bb32-da1e-459e-8038-8fd1e742978e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1263bb32-da1e-459e-8038-8fd1e742978e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a5766887-2346-44cd-8df0-f43b6eca462a":{"roots":{"references":[{"attributes":{},"id":"04765064-f1d2-4436-ad38-c367f9547708","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"408c4c3d-4464-4f64-83e9-64e4e159ffd6","subtype":"Figure","type":"Plot"}},"id":"a800fb9d-65ba-4a1f-8ef6-a6948183cb23","type":"PanTool"},{"attributes":{"callback":null},"id":"74fe3121-25ac-4469-8f8f-9b312438605f","type":"DataRange1d"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30b258f1-1d24-4705-91ba-858040ad492b","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd2de2d1-6769-4316-a0c6-fd079a433505","type":"Line"},{"attributes":{},"id":"0d294862-db24-4ded-8a88-9c38d58bcdb3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"408c4c3d-4464-4f64-83e9-64e4e159ffd6","subtype":"Figure","type":"Plot"}},"id":"444a7997-38aa-4671-8fd0-3dfbf0c05a67","type":"ResetTool"},{"attributes":{},"id":"2d95525b-743d-4762-a1da-1c25becc9e52","type":"BasicTicker"},{"attributes":{"formatter":{"id":"04765064-f1d2-4436-ad38-c367f9547708","type":"BasicTickFormatter"},"plot":{"id":"408c4c3d-4464-4f64-83e9-64e4e159ffd6","subtype":"Figure","type":"Plot"},"ticker":{"id":"612a83e4-5251-4324-882b-702236cce869","type":"BasicTicker"}},"id":"17215c23-b5f2-47f8-9282-a71dcf23753a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a800fb9d-65ba-4a1f-8ef6-a6948183cb23","type":"PanTool"},{"id":"899fc87a-36de-444c-8b06-923b4192fcda","type":"WheelZoomTool"},{"id":"81620643-ca52-4303-a876-9a369a7f0654","type":"BoxZoomTool"},{"id":"6088ddf2-352c-48ff-91e3-44f261596d59","type":"SaveTool"},{"id":"444a7997-38aa-4671-8fd0-3dfbf0c05a67","type":"ResetTool"},{"id":"900c297e-a19d-4b0e-8b90-99053f29d937","type":"HelpTool"}]},"id":"871dad4d-b427-4be0-8380-05b65af55359","type":"Toolbar"},{"attributes":{"plot":{"id":"408c4c3d-4464-4f64-83e9-64e4e159ffd6","subtype":"Figure","type":"Plot"}},"id":"6088ddf2-352c-48ff-91e3-44f261596d59","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.000625,0.00125,0.001875,0.0025,0.003125,0.00375,0.004375,0.005,0.005625,0.00625,0.006875,0.0075,0.008125,0.00875,0.009375,0.01,0.010625,0.01125,0.011875,0.0125,0.013125,0.01375,0.014375,0.015,0.015625,0.01625,0.016875,0.0175,0.018125,0.01875,0.019375,0.02,0.020625,0.02125,0.021875000000000002,0.0225,0.023125,0.02375,0.024375,0.025,0.025625000000000002,0.02625,0.026875,0.0275,0.028125,0.02875,0.029375000000000002,0.03,0.030625,0.03125,0.031875,0.0325,0.033125,0.03375,0.034375,0.035,0.035625000000000004,0.03625,0.036875,0.0375,0.038125,0.03875,0.039375,0.04,0.040625,0.04125,0.041875,0.0425,0.043125000000000004,0.043750000000000004,0.044375,0.045,0.045625,0.04625,0.046875,0.0475,0.048125,0.04875,0.049375,0.05,0.050625,0.051250000000000004,0.051875000000000004,0.0525,0.053125,0.05375,0.054375,0.055,0.055625,0.05625,0.056875,0.0575,0.058125,0.058750000000000004,0.059375000000000004,0.06,0.060625,0.06125,0.061875,0.0625,0.063125,0.06375,0.064375,0.065,0.065625,0.06625,0.066875,0.0675,0.068125,0.06875,0.069375,0.07,0.07062500000000001,0.07125000000000001,0.07187500000000001,0.0725,0.073125,0.07375,0.074375,0.075,0.075625,0.07625,0.076875,0.0775,0.078125,0.07875,0.079375,0.08,0.080625,0.08125,0.081875,0.0825,0.083125,0.08375,0.084375,0.085,0.085625,0.08625000000000001,0.08687500000000001,0.08750000000000001,0.088125,0.08875,0.089375,0.09,0.090625,0.09125,0.091875,0.0925,0.093125,0.09375,0.094375,0.095,0.095625,0.09625,0.096875,0.0975,0.098125,0.09875,0.099375,0.1,0.100625,0.10125,0.10187500000000001,0.10250000000000001,0.10312500000000001,0.10375000000000001,0.104375,0.105,0.105625,0.10625,0.106875,0.1075,0.108125,0.10875,0.109375,0.11,0.110625,0.11125,0.111875,0.1125,0.113125,0.11375,0.114375,0.115,0.115625,0.11625,0.116875,0.11750000000000001,0.11812500000000001,0.11875000000000001,0.11937500000 ...

# %%
p = figure(title="roll gyrodiff vs actuators")
p.line(df.time, df.derivgyroX)
p.extra_y_ranges = { 'actuation' : Range1d(min(df.desiredX), max(df.desiredX)) }
p.line(df.time, df.desiredX, y_range_name='actuation', color="red")
p.add_layout(LinearAxis(y_range_name="actuation"), 'right')

show(p)

# If we differentiate the gyro, the shape is more clearly related, but boy is
# there a lot of noise.
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="602693ee-e15f-49bb-9fad-f7960b827bcd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#602693ee-e15f-49bb-9fad-f7960b827bcd").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("602693ee-e15f-49bb-9fad-f7960b827bcd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '602693ee-e15f-49bb-9fad-f7960b827bcd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"09807aac-c27d-454e-9d53-355ca9e72baa":{"roots":{"references":[{"attributes":{"plot":null,"text":"roll gyrodiff vs actuators"},"id":"28cf7822-13f4-4886-a0fd-4b74e05176b8","type":"Title"},{"attributes":{"plot":{"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"}},"id":"8b076e8d-f884-4c5d-919b-b6aa95eed4fe","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"}},"id":"0ffa70cb-172a-4105-8bf3-014948d369ef","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b78bd44-1d20-4cd3-88ba-620199be7a94","type":"Line"},{"attributes":{"below":[{"id":"d358f9de-5f39-4311-9e25-812d94ddf6b5","type":"LinearAxis"}],"extra_y_ranges":{"actuation":{"id":"834ce0e0-aa18-41e2-96c8-4efcda334802","type":"Range1d"}},"left":[{"id":"5b099128-7eb7-4df1-bdb5-5e182e1ea163","type":"LinearAxis"}],"renderers":[{"id":"d358f9de-5f39-4311-9e25-812d94ddf6b5","type":"LinearAxis"},{"id":"e097a496-ce8f-4cf1-b068-69b2ec0a462b","type":"Grid"},{"id":"5b099128-7eb7-4df1-bdb5-5e182e1ea163","type":"LinearAxis"},{"id":"eed8c5eb-1c5d-4ca8-92bc-1ead329455f7","type":"Grid"},{"id":"c5e21c57-58d9-437c-a8ae-73a073648af4","type":"BoxAnnotation"},{"id":"ef2e0a24-ff3b-4390-8535-23a48f6a60dd","type":"GlyphRenderer"},{"id":"fee103ee-fc8f-46a7-9c2b-81a09b83ec96","type":"GlyphRenderer"},{"id":"1385df2e-949a-49fe-8f64-a862daf41371","type":"LinearAxis"}],"right":[{"id":"1385df2e-949a-49fe-8f64-a862daf41371","type":"LinearAxis"}],"title":{"id":"28cf7822-13f4-4886-a0fd-4b74e05176b8","type":"Title"},"tool_events":{"id":"7a3cc072-99b0-4185-99fb-522721a0ffba","type":"ToolEvents"},"toolbar":{"id":"7c38414b-15cd-44da-be23-95487eced40d","type":"Toolbar"},"x_range":{"id":"26d50f9e-d90b-4c54-9834-1adb11b98b3f","type":"DataRange1d"},"y_range":{"id":"7f3d6ed4-ea6e-4672-a418-db7e606629d1","type":"DataRange1d"}},"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"},"ticker":{"id":"79cee3ab-4bff-4da8-a1f4-60e5832ccb24","type":"BasicTicker"}},"id":"eed8c5eb-1c5d-4ca8-92bc-1ead329455f7","type":"Grid"},{"attributes":{"callback":null},"id":"26d50f9e-d90b-4c54-9834-1adb11b98b3f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"47e8c49d-6e7f-493b-abd9-98ac7d418c1b","type":"BasicTickFormatter"},"plot":{"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"},"ticker":{"id":"79cee3ab-4bff-4da8-a1f4-60e5832ccb24","type":"BasicTicker"}},"id":"5b099128-7eb7-4df1-bdb5-5e182e1ea163","type":"LinearAxis"},{"attributes":{},"id":"a35557fe-619b-4791-aa72-c9b177e30756","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"6b2ee2e6-3001-49bc-afcb-81e31bfb0385","type":"ColumnDataSource"},"glyph":{"id":"2ea737c0-f530-46f5-bc7a-59237a2ee28c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c069df0e-3528-4bb6-b31f-e4b64e8ef5fc","type":"Line"},"selection_glyph":null},"id":"ef2e0a24-ff3b-4390-8535-23a48f6a60dd","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2ea737c0-f530-46f5-bc7a-59237a2ee28c","type":"Line"},{"attributes":{},"id":"79cee3ab-4bff-4da8-a1f4-60e5832ccb24","type":"BasicTicker"},{"attributes":{"formatter":{"id":"f691e2f5-0c8e-453f-98e3-5a069488a63a","type":"BasicTickFormatter"},"plot":{"id":"6924f0c7-9142-4353-9676-e7d2a8061844","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c1bf2fa-5007-49ae-ac17-5f076f88a6f4","type":"BasicTicker"}},"id":"d358f9de-5f39-4311-9e25-812d94ddf6b5","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_ ...

# %%
p = figure(title="filtered roll gyrodiff vs actuators")
p.line(df.time, df.derivfilteredX)
p.extra_y_ranges = { 'actuation' : Range1d(min(df.desiredX), max(df.desiredX)) }
p.line(df.time, df.desiredX, y_range_name='actuation', color="red")
p.add_layout(LinearAxis(y_range_name="actuation"), 'right')

show(p)

# Low pass filtering clearly helps.  Now let's get down to business of finding how the input
# relates to the output.
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="64ecfe20-37f5-435d-a3b1-5f5aca75e4bf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#64ecfe20-37f5-435d-a3b1-5f5aca75e4bf").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64ecfe20-37f5-435d-a3b1-5f5aca75e4bf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64ecfe20-37f5-435d-a3b1-5f5aca75e4bf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b8455274-3b9d-46a5-ac7d-76da268430d6":{"roots":{"references":[{"attributes":{},"id":"904c0716-4505-4c1f-97a8-ecdc00cf882d","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ec1809a2-f6dd-4165-a6a6-ff6e4b3cfee1","type":"Line"},{"attributes":{},"id":"e11bb208-9e75-4174-8a75-75074be7056a","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b936179f-b1a0-49ab-b5c2-31b819225268","type":"PanTool"},{"id":"75ec3dfe-0b1b-47f3-89b4-f57b3a090702","type":"WheelZoomTool"},{"id":"8dc4758c-080d-4dc3-88a7-696404f8789c","type":"BoxZoomTool"},{"id":"5be50ba4-68df-4101-af08-00cbf7f7ea52","type":"SaveTool"},{"id":"708e3abe-eaa2-405a-9d24-b50edac2610b","type":"ResetTool"},{"id":"2b4839a9-95cd-4f0c-a644-d9872c8e9757","type":"HelpTool"}]},"id":"5f1075ec-4583-42e9-bbaf-f04c37c60a61","type":"Toolbar"},{"attributes":{"plot":{"id":"5a47e43f-d6a3-4ad4-982e-58e70499cdf9","subtype":"Figure","type":"Plot"},"ticker":{"id":"04439aa8-762f-4749-8818-a3e280915bd2","type":"BasicTicker"}},"id":"dd42c7b3-fdb5-47b1-8a06-0fa09cb6fe3c","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.000625,0.00125,0.001875,0.0025,0.003125,0.00375,0.004375,0.005,0.005625,0.00625,0.006875,0.0075,0.008125,0.00875,0.009375,0.01,0.010625,0.01125,0.011875,0.0125,0.013125,0.01375,0.014375,0.015,0.015625,0.01625,0.016875,0.0175,0.018125,0.01875,0.019375,0.02,0.020625,0.02125,0.021875000000000002,0.0225,0.023125,0.02375,0.024375,0.025,0.025625000000000002,0.02625,0.026875,0.0275,0.028125,0.02875,0.029375000000000002,0.03,0.030625,0.03125,0.031875,0.0325,0.033125,0.03375,0.034375,0.035,0.035625000000000004,0.03625,0.036875,0.0375,0.038125,0.03875,0.039375,0.04,0.040625,0.04125,0.041875,0.0425,0.043125000000000004,0.043750000000000004,0.044375,0.045,0.045625,0.04625,0.046875,0.0475,0.048125,0.04875,0.049375,0.05,0.050625,0.051250000000000004,0.051875000000000004,0.0525,0.053125,0.05375,0.054375,0.055,0.055625,0.05625,0.056875,0.0575,0.058125,0.058750000000000004,0.059375000000000004,0.06,0.060625,0.06125,0.061875,0.0625,0.063125,0.06375,0.064375,0.065,0.065625,0.06625,0.066875,0.0675,0.068125,0.06875,0.069375,0.07,0.07062500000000001,0.07125000000000001,0.07187500000000001,0.0725,0.073125,0.07375,0.074375,0.075,0.075625,0.07625,0.076875,0.0775,0.078125,0.07875,0.079375,0.08,0.080625,0.08125,0.081875,0.0825,0.083125,0.08375,0.084375,0.085,0.085625,0.08625000000000001,0.08687500000000001,0.08750000000000001,0.088125,0.08875,0.089375,0.09,0.090625,0.09125,0.091875,0.0925,0.093125,0.09375,0.094375,0.095,0.095625,0.09625,0.096875,0.0975,0.098125,0.09875,0.099375,0.1,0.100625,0.10125,0.10187500000000001,0.10250000000000001,0.10312500000000001,0.10375000000000001,0.104375,0.105,0.105625,0.10625,0.106875,0.1075,0.108125,0.10875,0.109375,0.11,0.110625,0.11125,0.111875,0.1125,0.113125,0.11375,0.114375,0.115,0.115625,0.11625,0.116875,0.11750000000000001,0.11812500000000001,0.11875000000000001,0.11937500000000001,0.12,0.120625,0.12125,0.121875,0.1225,0.123125,0.12375,0.124375,0.125,0.12562500000000001,0.12625,0.12687500000000002,0.1275,0.128125,0.12875,0.129375,0.13,0.130625,0.13125,0.131875,0.1325,0.133125,0.13375,0.134375,0.135,0.135625,0.13625,0.136875,0.1375,0.138125,0.13875,0.139375,0.14,0.140625,0.14125000000000001,0.141875,0.14250000000000002,0.143125,0.14375000000000002,0.144375,0.145,0.145625,0.14625,0.146875,0.1475,0.148125,0.14875,0.149375,0.15,0.150625,0.15125,0.151875,0.1525,0.153125,0.15375,0.154375,0.155,0.155625,0.15625,0.15687500000000001,0.1575,0.15812500000000002,0.15875,0.15937500000000002,0.16,0.160625,0.16125,0.161875,0.1625,0.163125,0.16375,0.164375,0.165,0.165625,0.16625,0.166875,0.1675,0.168125,0.16875,0.169375,0.17,0.170625,0.17125,0.171875,0.17250000000000001,0.173125,0.17375000000000002,0.174375,0.17500000000000002,0.175625,0.17625,0.176875,0.1775,0.178125,0.17875,0.179375,0.18,0.1806 ...

# %%
def find_real_peak(series):
    p = np.argmax(series)
    
    min_idx = p - 3
    
    if (min_idx < 0):
        min_idx = 0
    
    max_idx = p + 3
    
    if (max_idx >= len(series)):
        max_idx = len(series) - 1
    
    fit = np.polyfit(range(min_idx, max_idx+1), series[min_idx:max_idx+1], 2)
    
    peak = fit[1] / -fit[0] / 2

    return fit[1] / -fit[0] / 2



# For now, we just want to figure the parameters that existing autotune
# uses, but in a more accurate and more robust way.  In the future we'll
# do much fancier things.

# So, for each of the three axes, let's perform fourier analysis in order to
# correlate the differentiated, filtered gyros vs. the actuator command.
# This will tell us the delay, or tau.  From 

def compute_axis(desired_series, diff_gyro_series, filter_order=2,
                 percentile_cutoff=2, plot_tau=True, series_cutoff=2,
                 axis_name=""):
    desired_fft = fftpack.fft(desired_series)
    diff_fft = fftpack.fft(diff_gyro_series)

    desired_fft_r = -desired_fft.conjugate()

    correl = fftpack.ifft(desired_fft_r * diff_fft) 

    tau_offset = find_real_peak(np.abs(correl[0:len(correl)/series_cutoff]))
    
    if plot_tau:
        p = figure(title="%s delay time vs. correlation"%(axis_name), y_axis_type = "log")
        p.line(np.linspace(0,len(correl) / 2 * time_step, len(correl) / 2), np.abs(correl[0:len(correl)/2]))
        tauspan = Span(location=tau_offset * time_step, dimension='height', line_color='red', line_width=1)
        #bogospan = Span(location=.0168, dimension='height', line_color='green', line_width=1)
        #p.renderers.extend([bogospan])
        p.renderers.extend([tauspan])
        show(p)

    # half cycles per sample.e
    filter_edge = filter_order / tau_offset / 3.14159 / 1.414

    # A nth order filter doesn't result in n* the delay with bessel
    # design technique.  1.22 is a fudge factor for order 3.  Not sure where
    # 1.22 comes from :D
    db, da = signal.iirfilter(filter_order, [filter_edge], btype='lowpass', ftype='butter')

    #w, gd = signal.group_delay((db, da))
    #p = figure()
    #p.line(w, gd)
    #show(p)
    
    desired_series = pandas.concat([desired_series, desired_series], ignore_index = True)
    
    delayedact = signal.lfilter(db, da, desired_series)
    
    delayedact = delayedact[len(delayedact)/2:]
    
    # Now compare the response magnitude of the filtered waveform vs. the
    # differentiated gyro series, to compute beta and then the bias.
    span_desired = np.percentile(delayedact, [percentile_cutoff, 100-percentile_cutoff])

    span_gyrodiff = np.percentile(diff_gyro_series, [percentile_cutoff, 100-percentile_cutoff])
    
    
    lin_gain = (span_gyrodiff[1]-span_gyrodiff[0]) / (span_desired[1]-span_desired[0])
    
    bias = delayedact.mean() * lin_gain - diff_gyro_series.mean()

    return (tau_offset, lin_gain, bias, delayedact * lin_gain - bias)
 
def compute_axis_by_name(series_name, do_plots=True, series_cutoff=2):
    desired = df['desired'+series_name]
    deriv_filtered = df['derivfiltered'+series_name]
    
    tau_offset, lin_gain, bias, adjact = compute_axis(desired, deriv_filtered, plot_tau=do_plots,
                                                     series_cutoff=series_cutoff,
                                                     axis_name=series_name)
    
    df['adjdesired' + series_name] = pandas.Series(adjact)
    
    print "Axis %s: tau=%.1f samples (%0.2f ms / %0.3f)"%(series_name, tau_offset, tau_offset*time_step*1000, math.log(tau_offset*time_step))
    print "\tgain=%0.1f (beta=%0.3f), bias=%0.1f"%(lin_gain, math.log(lin_gain / time_step), bias)
    
    if (do_plots):
        p = figure(title="%s shifted to line up"%(series_name))
        
        p.line(df.time, deriv_filtered)
        p.line(df.time, adjact, color="green")

        show(p)
        
        p = figure(title="residual %s"%(series_name))
        
        p.line(df.time, deriv_filtered - adjact)
        show(p)

compute_axis_by_name("X", series_cutoff=10)
compute_axis_by_name("Y", series_cutoff=5)
compute_axis_by_name("Z", series_cutoff=5)

print np.correlate(df.derivfilteredX, df.derivfilteredX)
print np.correlate(df.derivfilteredX, df.derivfilteredY)
print np.correlate(df.derivfilteredX, df.derivfilteredZ)
print np.correlate(df.derivfilteredY, df.derivfilteredY)
print np.correlate(df.derivfilteredY, df.derivfilteredZ)
print np.correlate(df.derivfilteredZ, df.derivfilteredZ)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="65eb601a-d28c-473d-b5f8-01973adfad49"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#65eb601a-d28c-473d-b5f8-01973adfad49").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65eb601a-d28c-473d-b5f8-01973adfad49");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65eb601a-d28c-473d-b5f8-01973adfad49' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"680c6bff-b6a9-4810-8cb4-e3fc2dac42b4":{"roots":{"references":[{"attributes":{"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"}},"id":"7fd43987-5061-4849-a857-a6a766b57f05","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fcf258b-fff6-4583-bc10-d34e746a6d56","type":"Line"},{"attributes":{"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"}},"id":"c6c1dcd4-7b0b-4ac5-a17a-c4d147e0c28f","type":"PanTool"},{"attributes":{},"id":"2c46d8e4-8d11-4270-a359-938e08552206","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"53a9c26c-8a85-4ba7-81d1-d3e9f6d64c06","type":"BoxAnnotation"},"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"}},"id":"13756ea1-571d-4746-897e-a08588b8d377","type":"BoxZoomTool"},{"attributes":{},"id":"82bef510-1b5b-45ed-bf77-1804040eba75","type":"ToolEvents"},{"attributes":{"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c591175-60ea-4890-ac1a-8c1732e41d3f","type":"BasicTicker"}},"id":"675f1af5-db53-45bc-8025-4fca3c582359","type":"Grid"},{"attributes":{"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"}},"id":"b91e3676-81b4-45ca-bc62-9d72450b596a","type":"WheelZoomTool"},{"attributes":{"ticker":null},"id":"375db5a8-4bb8-4ac5-a611-f30395dc659d","type":"LogTickFormatter"},{"attributes":{"plot":{"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"}},"id":"b84e2005-21ae-4cd0-8a60-7d425355c630","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"53a9c26c-8a85-4ba7-81d1-d3e9f6d64c06","type":"BoxAnnotation"},{"attributes":{"dimension":"height","line_color":{"value":"red"},"location":0.024196288581554135,"plot":null},"id":"6447223f-c294-478a-8419-50243b86c7a9","type":"Span"},{"attributes":{},"id":"3c591175-60ea-4890-ac1a-8c1732e41d3f","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2adac8e-7d8d-44c3-a0e0-809e4c25b673","type":"Line"},{"attributes":{"below":[{"id":"99faace4-68d6-47d1-9140-b4d25180efab","type":"LinearAxis"}],"left":[{"id":"3c4250ee-7474-47b4-bfd3-c8fbb2cb871f","type":"LogAxis"}],"renderers":[{"id":"99faace4-68d6-47d1-9140-b4d25180efab","type":"LinearAxis"},{"id":"675f1af5-db53-45bc-8025-4fca3c582359","type":"Grid"},{"id":"3c4250ee-7474-47b4-bfd3-c8fbb2cb871f","type":"LogAxis"},{"id":"b8d45f85-c9d7-4447-957c-1ab4a9b387b8","type":"Grid"},{"id":"53a9c26c-8a85-4ba7-81d1-d3e9f6d64c06","type":"BoxAnnotation"},{"id":"ddd2f6b6-f8d5-4bf6-b523-24c8bad08dbc","type":"GlyphRenderer"},{"id":"6447223f-c294-478a-8419-50243b86c7a9","type":"Span"}],"title":{"id":"c00e6ce6-1d4a-4c56-992e-6ba00b3dc73a","type":"Title"},"tool_events":{"id":"82bef510-1b5b-45ed-bf77-1804040eba75","type":"ToolEvents"},"toolbar":{"id":"a6dcec42-4efe-45eb-8a8c-746e8efbea4c","type":"Toolbar"},"x_range":{"id":"facb3fbd-a3fe-4b4f-9374-d93e0390ba30","type":"DataRange1d"},"y_mapper_type":"log","y_range":{"id":"3a324504-fb08-4f21-8659-32d6150f481e","type":"DataRange1d"}},"id":"6c44cfb7-c32b-42e9-86ab-a6e1447a7b1f","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"facb3fbd-a3fe-4b4f-9374-d93e0390ba30","type":"DataRange1d"},{"attributes":{"num_minor_ticks":10},"id":"94b84e50-3860-4da9-96c9-58ced0360b41","type":"LogTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c6c1dcd4-7b0b-4ac5-a17a-c4d147e0c28f","type":"PanTool"},{"id":"b91e3676-81b4-45ca-bc62-9d72450b596a","type":"WheelZoomTool"},{"id":"13756 ...
# Axis X: tau=38.7 samples (24.20 ms / -3.722)
# 	gain=16.1 (beta=10.156), bias=1.3
#     <div class="bk-root">
#         <div class="plotdiv" id="f3a9f8d1-6be7-4fed-9acd-681f45b96f90"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f3a9f8d1-6be7-4fed-9acd-681f45b96f90").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3a9f8d1-6be7-4fed-9acd-681f45b96f90");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '
etTool"},{"id":"5561cb2c-fc80-40a9-a3a1-119ca4cf3724","type":"HelpTool"}]},"id":"045b5064-b773-4fb7-ba92-1fc004f4ba0c","type":"Toolbar"},{"attributes":{"overlay":{"id":"085d5732-4dfb-4135-9bc7-28b086ce99df","type":"BoxAnnotation"},"plot":{"id":"ace26157-c10b-4e1e-86b8-3faa7bbf8ee4","subtype":"Figure","type":"Plot"}},"id":"b14c8a03-d2cc-4fd4-9e55-591d832acec1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"ace26157-c10b-4e1e-86b8-3faa7bbf8ee4","subtype":"Figure","type":"Plot"}},"id":"f96bb486-268f-4a2f-89d7-1dcd96c4d143","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.000625,0.00125,0.001875,0.0025,0.003125,0.00375,0.004375,0.005,0.005625,0.00625,0.006875,0.0075,0.008125,0.00875,0.009375,0.01,0.010625,0.01125,0.011875,0.0125,0.013125,0.01375,0.014375,0.015,0.015625,0.01625,0.016875,0.0175,0.018125,0.01875,0.019375,0.02,0.020625,0.02125,0.021875000000000002,0.0225,0.023125,0.02375,0.024375,0.025,0.025625000000000002,0.02625,0.026875,0.0275,0.028125,0.02875,0.029375000000000002,0.03,0.030625,0.03125,0.031875,0.0325,0.033125,0.03375,0.034375,0.035,0.035625000000000004,0.03625,0.036875,0.0375,0.038125,0.03875,0.039375,0.04,0.040625,0.04125,0.041875,0.0425,0.043125000000000004,0.043750000000000004,0.044375,0.045,0.045625,0.04625,0.046875,0.0475,0.048125,0.04875,0.049375,0.05,0.050625,0.051250000000000004,0.051875000000000004,0.0525,0.053125,0.05375,0.054375,0.055,0.055625,0.05625,0.056875,0.0575,0.058125,0.058750000000000004,0.059375000000000004,0.06,0.060625,0.06125,0.061875,0.0625,0.063125,0.06375,0.064375,0.065,0.065625,0.06625,0.066875,0.0675,0.068125,0.06875,0.069375,0.07,0.07062500000000001,0.07125000000000001,0.07187500000000001,0.0725,0.073125,0.07375,0.074375,0.075,0.075625,0.07625,0.076875,0.0775,0.078125,0.07875,0.079375,0.08,0.080625,0.08125,0.081875,0.0825,0.083125,0.08375,0.084375,0.085,0.085625,0.08625000000000001,0.08687500000000001,0.08750000000000001,0.088125,0.08875,0.089375,0.09,0.090625,0.09125,0.091875,0.0925,0.093125,0.09375,0.094375,0.095,0.095625,0.09625,0.096875,0.0975,0.098125,0.09875,0.099375,0.1,0.100625,0.10125,0.10187500000000001,0.10250000000000001,0.10312500000000001,0.10375000000000001,0.104375,0.105,0.105625,0.10625,0.106875,0.1075,0.108125,0.10875,0.109375,0.11,0.110625,0.11125,0.111875,0.1125,0.113125,0.11375,0.114375,0.115,0.115625,0.11625,0.116875,0.11750000000000001,0.11812500000000001,0.11875000000000001,0.11937500000000001,0.12,0.120625,0.12125,0.121875,0.1225,0.123125,0.12375,0.124375,0.125,0.12562500000000001,0.12625,0.12687500000000002,0.1275,0.128125,0.12875,0.129375,0.13,0.130625,0.13125,0.131875,0.1325,0.133125,0.13375,0.134375,0.135,0.135625,0.13625,0.136875,0.1375,0.138125,0.13875,0.139375,0.14,0.140625,0.14125000000000001,0.141875,0.14250000000000002,0.143125,0.14375000000000002,0.144375,0.145,0.145625,0.14625,0.146875,0.1475,0.148125,0.14875,0.149375,0.15,0.150625,0.15125,0.151875,0.1525,0.153125,0.15375,0.154375,0.155,0.155625,0.15625,0.15687500000000001 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="04084215-5420-4347-8329-3aa3b48b7230"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#04084215-5420-4347-8329-3aa3b48b7230").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04084215-5420-4347-8329-3aa3b48b7230");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04084215-5420-4347-8329-3aa3b48b7230' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
# ...
# Axis Z: tau=12.1 samples (7.58 ms / -4.882)
# 	gain=10.4 (beta=9.716), bias=-20.5
#     <div class="bk-root">
#         <div class="plotdiv" id="8fa8028c-3399-4246-aa6f-e40f2c172eeb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#8fa8028c-3399-4246-aa6f-e40f2c172eeb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8fa8028c-3399-4246-aa6f-e40f2c172eeb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8fa8028c-3399-4246-aa6f-e40f2c172eeb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"820b35ad-8b0b-4c78-9fbd-58d88099d77c":{"roots":{"references":[{"attributes":{"data_source":{"id":"d22cf8e2-d82f-4593-b811-10c990774a64","type":"ColumnDataSource"},"glyph":{"id":"9b76c381-af71-403e-8dc6-ec854530602a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"bf3efa05-326c-4f11-9fa6-802ab8365b0e","type":"Line"},"selection_glyph":null},"id":"9e7ac22d-6186-43b0-a904-7b424c18c48e","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7dcac43-5c50-40e2-a437-2faab7a7aa3a","type":"Line"},{"attributes":{"plot":{"id":"09645d4d-dda0-423f-8909-ae4a945afe22","subtype":"Figure","type":"Plot"}},"id":"7aa6ea84-ab20-438d-a41c-37f7b5909035","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"e85a3353-272a-4590-a813-c4a84317db18","type":"LinearAxis"}],"left":[{"id":"a29b35ab-cd5f-4a6b-8e0a-2d527f999c1f","type":"LinearAxis"}],"renderers":[{"id":"e85a3353-272a-4590-a813-c4a84317db18","type":"LinearAxis"},{"id":"2990eb6f-a032-4f53-ab01-066ef42a8683","type":"Grid"},{"id":"a29b35ab-cd5f-4a6b-8e0a-2d527f999c1f","type":"LinearAxis"},{"id":"903448e7-dd0a-44b8-8fd3-d2d713feb45f","type":"Grid"},{"id":"1475ac16-ce52-4634-a8c4-fa6cff9d3545","type":"BoxAnnotation"},{"id":"87636e96-0330-49f1-9e56-363b69727cf6","type":"GlyphRenderer"},{"id":"9e7ac22d-6186-43b0-a904-7b424c18c48e","type":"GlyphRenderer"}],"title":{"id":"886c3443-6510-4668-8eaf-d1070fce4b84","type":"Title"},"tool_events":{"id":"73147827-bf28-49c7-8e57-4899635459f6","type":"ToolEvents"},"toolbar":{"id":"11919a7e-4e52-4452-ba96-205a8469f391","type":"Toolbar"},"x_range":{"id":"1b16f574-bddd-491b-b395-ce84f6fbb725","type":"DataRange1d"},"y_range":{"id":"013bad44-145e-46fb-bb0d-9c6ef131528c","type":"DataRange1d"}},"id":"09645d4d-dda0-423f-8909-ae4a945afe22","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"76c53139-5fd3-454f-8fe9-52de66d9280f","type":"ColumnDataSource"},"glyph":{"id":"f7dcac43-5c50-40e2-a437-2faab7a7aa3a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d4def46d-5af5-4d03-9366-3587520ff89e","type":"Line"},"selection_glyph":null},"id":"87636e96-0330-49f1-9e56-363b69727cf6","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"1475ac16-ce52-4634-a8c4-fa6cff9d3545","type":"BoxAnnotation"},"plot":{"id":"09645d4d-dda0-423f-8909-ae4a945afe22","subtype":"Figure","type":"Plot"}},"id":"11be8251-4f24-4f31-864e-f2c2bd7fd5bb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"09645d4d-dda0-423f-8909-ae4a945afe22","subtype":"Figure","type":"Plot"}},"id":"7a080b37-a659-48fa-bee6-95ed6ba5e6ca","type":"SaveTool"},{"attributes":{},"id":"ffaf6763-4c18-4074-8745-4a624f10d490","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1475ac16-ce52-4634-a8c4-fa6cff9d3545","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"8bedaaa6-ab14-448c-8f0e-ea960747697f","type":"BasicTickFormatter"},"plot":{"id":"09645d4d-dda0-423f-8909-ae4a945afe22","subtype":"Figure","type":"Plot"},"ticker":{"id":"7dfc6864-0cd1-4900-a556-3b4a6865566a","type":"BasicTicker"}},"id":"e85a3353-272a-4590-a813-c4a84317db18","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.000625,0.00125,0.001875,0.0025,0.003125,0.00375,0.004375,0.005,0.005625,0.00625,0.006875,0.0075,0.008125,0.00875,0.009375,0.01,0.010625,0.01125,0.011875,0.0125,0.013125,0.01375,0.014375,0.015,0.015625,0.01625,0.016875,0.0175,0.018125,0.01875,0.019375,0.02,0.020625,0.02125,0.021875000000000002,0.0225,0.023125,0.02375,0.024375,0.025,0.025625000000000002,0.02625,0.026875,0.0275,0.028125,0.02875,0.029375000000000002,0.03,0.030625,0.03125,0.031875,0.0325,0.033125,0.03375,0.034375,0.035 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="c034bc97-e38d-4643-975d-e4411a7f2292"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c034bc97-e38d-4643-975d-e4411a7f2292").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c034bc97-e38d-4643-975d-e4411a7f2292");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c034bc97-e38d-4643-975d-e4411a7f2292' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"af369cba-a72d-403e-ba77-9a46a4607cb4":{"roots":{"references":[{"attributes":{"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"}},"id":"4b53065e-bc73-46ce-bb25-653d97f1fd02","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d03ca285-b3ec-4938-a6db-91e1d1afe31e","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"}},"id":"3d3df82d-685a-430e-b83d-ebca1cdfa6b8","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba9c1c53-66de-4aa9-b4d2-1a8bd21a228c","type":"Line"},{"attributes":{},"id":"7bdea382-b99f-4122-aebf-53824a5d4e16","type":"ToolEvents"},{"attributes":{"callback":null},"id":"82e375b2-3ee1-4182-8616-23348a28af11","type":"DataRange1d"},{"attributes":{"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"},"ticker":{"id":"18bc0740-142f-4526-8e67-e93f24648f3a","type":"BasicTicker"}},"id":"a733fcb6-4980-4350-8b3c-677ec28dbbd3","type":"Grid"},{"attributes":{},"id":"18bc0740-142f-4526-8e67-e93f24648f3a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"},"ticker":{"id":"0125dbc7-74b5-4cad-9872-131907b8cc8a","type":"BasicTicker"}},"id":"72c27d91-330a-4077-8d47-078ebdd431e8","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d8d294d-da9a-4ada-ad16-a37ed6f0ece8","type":"Line"},{"attributes":{"callback":null},"id":"f736e718-0e40-4ab5-a15a-3c8b122569a8","type":"DataRange1d"},{"attributes":{"plot":null,"text":"residual Z"},"id":"db4dc439-ddfa-4782-ab7a-9e322432be7c","type":"Title"},{"attributes":{"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"}},"id":"b2cc2633-6592-43d3-860c-f12c7145f1a7","type":"PanTool"},{"attributes":{"formatter":{"id":"fb61a275-a3c0-4e8b-94ad-7ea5395f2a62","type":"BasicTickFormatter"},"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"},"ticker":{"id":"18bc0740-142f-4526-8e67-e93f24648f3a","type":"BasicTicker"}},"id":"b6fe3bd3-b387-41f7-9934-0d83e795f133","type":"LinearAxis"},{"attributes":{},"id":"fb61a275-a3c0-4e8b-94ad-7ea5395f2a62","type":"BasicTickFormatter"},{"attributes":{},"id":"0125dbc7-74b5-4cad-9872-131907b8cc8a","type":"BasicTicker"},{"attributes":{},"id":"06536a83-c403-4028-9f32-da361fbd3b4a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196","subtype":"Figure","type":"Plot"}},"id":"8cf9a9d4-2498-44ed-8e2b-e9bf4f6d8f0b","type":"HelpTool"},{"attributes":{"below":[{"id":"b6fe3bd3-b387-41f7-9934-0d83e795f133","type":"LinearAxis"}],"left":[{"id":"6c2c61ba-3fc2-46df-a464-ad7374d94967","type":"LinearAxis"}],"renderers":[{"id":"b6fe3bd3-b387-41f7-9934-0d83e795f133","type":"LinearAxis"},{"id":"a733fcb6-4980-4350-8b3c-677ec28dbbd3","type":"Grid"},{"id":"6c2c61ba-3fc2-46df-a464-ad7374d94967","type":"LinearAxis"},{"id":"72c27d91-330a-4077-8d47-078ebdd431e8","type":"Grid"},{"id":"d03ca285-b3ec-4938-a6db-91e1d1afe31e","type":"BoxAnnotation"},{"id":"383d1767-1195-4fe8-a6cd-8373f053c54b","type":"GlyphRenderer"}],"title":{"id":"db4dc439-ddfa-4782-ab7a-9e322432be7c","type":"Title"},"tool_events":{"id":"7bdea382-b99f-4122-aebf-53824a5d4e16","type":"ToolEvents"},"toolbar":{"id":"cdabcf01-e736-4709-9680-b7b54acacfa6","type":"Toolbar"},"x_range":{"id":"f736e718-0e40-4ab5-a15a-3c8b122569a8","type":"DataRange1d"},"y_range":{"id":"82e375b2-3ee1-4182-8616-23348a28af11","type":"DataRange1d"}},"id":"5ccff1e6-e1bd-4b5e-abbf-3d19a1470196"," ...
# [ 799082.37563244]
# [-9641.67862679]
# [ 176100.41835599]
# [ 477357.93750497]
# [ 118443.35285135]
# [ 488315.3730426]
